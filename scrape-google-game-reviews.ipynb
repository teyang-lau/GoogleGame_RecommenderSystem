# %%
import numpy as np 
import pandas as pd 
import json

# %%
games_detailed = pd.read_csv('../input/google-games-info/google_games_info_detailed.csv')

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews

# %%
tmp = games_detailed['appId']
#tmp = tmp[:2000]
#tmp = tmp[2000:4000]
#tmp = tmp[4000:6000]
tmp = tmp[6000:8000]

for c,g in enumerate(tmp):
    print(str(c) + ' ' + g)
    # init
    cum_count = 0
    all_result = []
    continuation_token = None # reset
    count = 100 # set number of reviews per query

    while cum_count < 1000:
        result, continuation_token = reviews(
            g,
            lang='en', # defaults to 'en'
            country='sg', # defaults to 'us'
            sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
            count=count, # defaults to 100
            continuation_token=continuation_token # defaults to None(load from the beginning)
        )
        all_result += result
        cum_count += count
    filename = './' + g + '.json'
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(all_result, json_file, indent=4, sort_keys=False, default=str)
